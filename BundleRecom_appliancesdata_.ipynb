# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
def load_data(file_path):
    # Define the column names
    column_names = ['asin', 'user_id', 'rating', 'timestamp']
    # Read the CSV file specifying that it does not have a header row and set the column names
    data = pd.read_csv(file_path, names=column_names, header=None)
    data['time'] = pd.to_datetime(data['timestamp'], unit='s')
    return data

# %%
# Load the dataset
df = load_data(
    '/kaggle/input/amazon-product-reviews-2018/Appliances.csv'
)

# %%
print(f'Size of dataset: {len(df):,}')
df.head()
# Out:
# Size of dataset: 602,777
#          asin         user_id  rating   timestamp       time
# 0  1118461304  A3NHUQ33CFH3VM     5.0  1385510400 2013-11-27
# 1  1118461304  A3SK6VNBQDNBJE     5.0  1383264000 2013-11-01
# 2  1118461304  A3SOFHUR27FO3K     5.0  1381363200 2013-10-10
# 3  1118461304  A1HOG1PYCAE157     5.0  1381276800 2013-10-09
# 4  1118461304  A26JGAM6GZMM4V     5.0  1378512000 2013-09-07

# %%
# # Filter out items rated below 3
# df = df[df['rating'] >= 3]
# print(f'Size of dataset: {len(df):,}')
# df.head()

# %%
# Filter out rarely rated products
# Define a threshold for minimum number of ratings
min_ratings_threshold = 50

# Calculate the number of ratings for each product
ratings_per_product = df['asin'].value_counts()

# Filter out products that have fewer than the threshold number of ratings
df_ = df[df['asin'].isin(
    ratings_per_product[ratings_per_product >= min_ratings_threshold].index
)].reset_index(drop=True)

# %%
print(f'Size of filtered dataset: {len(df_):,}')
df_.head()
# Out:
# Size of filtered dataset: 437,877
#          asin         user_id  rating   timestamp       time
# 0  B00004YWK2  A2UAX5WTHHKBBF     5.0  1197158400 2007-12-09
# 1  B00004YWK2  A2DHQKNGSYEHLS     3.0  1496707200 2017-06-06
# 2  B00004YWK2   AZ1F62XGI25RS     4.0  1489449600 2017-03-14
# 3  B00004YWK2  A2G1T9MVZLOHNG     5.0  1489363200 2017-03-13
# 4  B00004YWK2  A17109KS0DCTOG     5.0  1489104000 2017-03-10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Plotting the distribution of ratings
plt.figure(figsize=(10, 6))
df_['rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.grid(False)
plt.show()

# %%
from sklearn.utils import resample

# %%
# Separate the majority and minority classes
df_majority = df_[df_['rating'] == 5]
df_minority = df_[df_['rating'] != 5]

# Upsample the minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=len(df_majority),    # to match majority class
                                 random_state=42) # reproducible results

# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# %%
print(f'Size of upsampled dataset: {len(df_upsampled):,}')
df_upsampled.head()
# Out:
# Size of upsampled dataset: 614,974
#          asin         user_id  rating   timestamp       time
# 0  B00004YWK2  A2UAX5WTHHKBBF     5.0  1197158400 2007-12-09
# 3  B00004YWK2  A2G1T9MVZLOHNG     5.0  1489363200 2017-03-13
# 4  B00004YWK2  A17109KS0DCTOG     5.0  1489104000 2017-03-10
# 6  B00004YWK2  A370HU5Y7P5354     5.0  1485129600 2017-01-23
# 7  B00004YWK2   ALNRBNT7WMHCQ     5.0  1484524800 2017-01-16

# %%
# Plotting the distribution of ratings
plt.figure(figsize=(10, 6))
df_upsampled['rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.grid(False)
plt.show()

# %%
count_to_drop = len(df_upsampled[df_upsampled.rating == 5]) - len(df_upsampled[df_upsampled.rating == 4]) - 100000

# %%
df_dropped = df_upsampled.drop(df_upsampled[df_upsampled.rating == 5].sample(n=count_to_drop, random_state=42).index)
df_dropped = df_dropped.sample(frac=1).reset_index(drop=True)

# %%
print(f'Size of dropped dataset: {len(df_dropped):,}')
df_dropped.head()
# Out:
# Size of dropped dataset: 538,562
#          asin               user_id  rating   timestamp       time
# 0  B00GTZMHOW  A0085981OPK4A5A0J73F     3.0  1509408000 2017-10-31
# 1  B00E8KC36M         AD0AD8KW5XFXS     3.0  1490659200 2017-03-28
# 2  B00LQDAJ1U        A2JRDIIGYWX309     5.0  1532736000 2018-07-28
# 3  B000DZFTC6        A2VC3OOMHOU92X     5.0  1505088000 2017-09-11
# 4  B000AST3AK        A27VIPQ9ZF00L7     4.0  1482278400 2016-12-21

# %%
# Plotting the distribution of ratings
plt.figure(figsize=(10, 6))
df_dropped['rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.grid(False)
plt.show()

# %%
df_ = df_dropped

# %%
# Calculate product popularity
product_popularity = df_['asin'].value_counts()

# Create a bar chart
plt.figure(figsize=(12, 6))
product_popularity[:20].plot(kind='bar')  # Plot only the top 20 products
plt.title('Product Popularity (Top 20)')
plt.xlabel('Product (ASIN)')
plt.ylabel('Number of Ratings')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate user activity
user_activity = df_['user_id'].value_counts()

# Create a histogram
plt.figure(figsize=(8, 6))
plt.hist(user_activity, bins=30, log=True)  # Log scale for better visualization
plt.title('Distribution of User Activity')
plt.xlabel('Number of Ratings')
plt.ylabel('Number of Users')
plt.show()

# %%
import dask.dataframe as dd

# %%
# Create a Dask DataFrame from the original DataFrame
ddf = dd.from_pandas(df_, npartitions=10)

# Remove duplicates based on 'user_id' and 'asin'
ddf = ddf.drop_duplicates(subset=['user_id', 'asin'])

# Add a new column 'interaction' and set its value to 1 for all rows
ddf['interaction'] = 1

# Compute the result and convert it back to a pandas DataFrame
df_copy = ddf.compute()

# Create the user-item matrix using the 'pivot_table' function
user_item_matrix = df_copy.pivot_table(index='user_id', columns='asin', values='interaction', fill_value=0)

# %%
from surprise import Reader, Dataset, SVD, accuracy
from surprise.model_selection import train_test_split

# %%
# Load data into suitable data type for surprise package
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df_[['user_id', 'asin', 'rating']], reader)

# %%
# Split the data into training and test sets
trainset, testset = train_test_split(data, test_size=0.25)

# %%
# Set up the SVD algorithm
algorithm = SVD(n_factors=52, n_epochs=50, lr_all=0.040474590755288455, reg_all=0.00529760490356965, random_state=42)

# %%
# Train the model on the training set
algorithm.fit(trainset)

# Predict on the test set and calculate RMSE, MSE and MAE
predictions = algorithm.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.7844

# %%
# Get recommendations for a single user
def get_top_n_recommendations(user_id, n=10):
    # Check which items the user has already rated
    rated_items = df_[df_['user_id'] == user_id]['asin'].tolist()

    # Predict ratings for all items not rated by this user
    all_items = df_['asin'].unique()
    unrated_items = [item for item in all_items if item not in rated_items]

    # Predict ratings for the unrated items
    predictions = [algorithm.predict(user_id, item) for item in unrated_items]

    # Get the top n recommendations
    top_n = sorted(predictions, key=lambda x: x.est, reverse=True)[:n]

    return [(pred.iid, pred.est) for pred in top_n]

# %%
# randomly select a user id
user_id = df_['user_id'].sample().item()
print(f'Selected User ID: {user_id}')

recommendations = get_top_n_recommendations(user_id, 10)
print(f'Top 10 recommended items for user {user_id}:')
for item, rating in recommendations:
    print(f'Item: {item}, Estimated Rating: {rating}')
# Out:
# Selected User ID: A1YDEC4MC0229G
# Top 10 recommended items for user A1YDEC4MC0229G:
# Item: B01CC7LSEA, Estimated Rating: 5
# Item: B0050KKS5C, Estimated Rating: 5
# Item: B0014CN8Y8, Estimated Rating: 5
# Item: B00DJVIU18, Estimated Rating: 5
# Item: B006H7HB7K, Estimated Rating: 5
# Item: B00D6MDETI, Estimated Rating: 5
# Item: B01CKFSCOS, Estimated Rating: 5
# Item: B003YKPAQC, Estimated Rating: 5
# Item: B01CC87G86, Estimated Rating: 5
# Item: B00DM8J11Q, Estimated Rating: 5

# %%
# Extract the top three item IDs from the recommendations
top_three_item_ids = [item[0] for item in recommendations[:3]]

print(f'Top 3 recommended item IDs for user {user_id}:\n{top_three_item_ids}')
# Out:
# Top 3 recommended item IDs for user A1YDEC4MC0229G:
# ['B01CC7LSEA', 'B0050KKS5C', 'B0014CN8Y8']

# %%
# Define the columns that are relevant to your analysis
relevant_columns = ['category', 'description', 'title', 'brand', 'feature','main_cat', 'asin']

def load_meta_data(file_path):
    data = pd.read_json(file_path, lines=True)
    data = data[relevant_columns]
    return data

# %%
# Load the whole dataset
metadata = load_meta_data(
    '/kaggle/input/amazon-product-reviews-2018/meta_Appliances.json'
)

# %%
print(f'Size of meta dataset: {len(metadata):,}')
metadata.head()
# Out:
# Size of meta dataset: 30,445
#                                             category  \
# 0  [Appliances, Refrigerators, Freezers & Ice Mak...
# 1  [Appliances, Refrigerators, Freezers & Ice Mak...
# 2              [Appliances, Parts &amp; Accessories]
# 3                  [Appliances, Parts & Accessories]
# 4  [Appliances, Parts & Accessories, Range Parts ...
#
#                                          description  \
# 0                                                 []
# 1  [2 X Tupperware Pure & Fresh Unique Covered Co...
# 2                                                 []
# 3  [Multi purpost descaler, especially suited to ...
# 4  [Full gauge and size beveled-edge; furnished w...
#
#                                                title           brand  \
# 0  Tupperware Freezer Square Round Container Set ...      Tupperware
# 1  2 X Tupperware Pure &amp; Fresh Unique Covered...      Tupperware
# 2                    The Cigar - Moments of Pleasure  The Cigar Book
# 3               Caraselle 2X 50G Appliance Descalene       Caraselle
# 4  EATON Wiring 39CH-SP-L Arrow Hart 1-Gang Chrom...    EATON Wiring
#
#                                              feature  \
# 0  [Each 3-pc. set includes two 7/8-cup/200 mL an...
# 1  [2 X Tupperware Pure & Fresh Unique Covered Co...
# 2                                                 []
# 3                                                 []
# 4  [Returns will not be honored on this closeout ...
#
#                    main_cat        asin
# 0                Appliances  7301113188
# 1                Appliances  7861850250
# 2               Amazon Home  8792559360
# 3  Tools & Home Improvement  9792954481
# 4  Tools & Home Improvement  B00002N5EL

# %%
from wordcloud import WordCloud

# %%
# Combine all product descriptions into a single string
descriptions = [item[0] for item in metadata['description'] if len(item) > 0]
text = ' '.join(descriptions)
text = text.replace('br', '')

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import random

# %%
# Define the target ASIN
target_asin = random.choice(top_three_item_ids)
print(f'Target ASIN: {target_asin}')

# Filter the DataFrame to find the product with the specified ASIN
target_item = metadata.loc[metadata['asin'] == target_asin]

# Check if the product was found
if target_item.empty:
    print(f"No product found with ASIN: {target_asin}")
target_item
# Out:
# Target ASIN: B01CC7LSEA
#                                                 category  \
# 28879  [Appliances, Parts & Accessories, Refrigerator...
#
#                                              description  \
# 28879  [, <strong>Meet Waterdrop Advanced</strong>, <...
#
#                                                    title      brand  \
# 28879  Waterdrop NSF 53&amp;42 Certified Refrigerator...  Waterdrop
#
#                                                  feature  \
# 28879  [NSF 53 CERTIFIED: Reduces specific health-rel...
#
#                        main_cat        asin
# 28879  Tools & Home Improvement  B01CC7LSEA

# %%
# # Randomly select 20,000 items from the DataFrame
# subset_data = metadata.sample(n=20000, random_state=42)  # Use a fixed random state for reproducibility
subset_data = metadata

# %%
import re
from bs4 import BeautifulSoup

# %%
# Function to flatten and combine text attributes
def flatten_and_combine(row):
    flattened_elements = []
    for col in row:
        if isinstance(col, list):
            # If it's a list, ensure it's not empty
            if col:  # Check if the list is not empty
                # Convert the list to a space-separated string
                flattened_elements.append(' '.join(str(x) for x in col))
        elif isinstance(col, str):
            # If it's a string, ensure it's not empty
            if col.strip():  # Check if it's not an empty string
                flattened_elements.append(col)

    # Join all non-empty elements into a single string
    combined_text = ' '.join(flattened_elements).strip()  # Strip leading/trailing spaces
    return combined_text

# %%
# Function to remove HTML tags from a given text with validation
def clean_text(text):
    # Normalize whitespace
    text = re.sub(r'\s+', ' ', text)

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # Remove file paths and filenames with extensions commonly found in descriptions
    text = re.sub(r'\S+\.(jpg|jpeg|png|gif|bmp|txt|pdf|docx|xlsx)\b', '', text, flags=re.I)

    # Strip HTML content if any
    if '<' in text and '>' in text:
        soup = BeautifulSoup(text, 'html.parser')
        text = soup.get_text(separator=' ', strip=True)

    # Optionally, remove all punctuation (can be customized based on need)
    text = re.sub(r'[^\w\s]', '', text)

    # Convert to lower case
    text = text.lower()

    return text.strip()

# %%
# Define the relevant columns for combining text
important_columns = ['category', 'description', 'title', 'brand', 'feature', 'main_cat']

# Apply the flatten-and-combine function to create the 'combined_text' column
subset_data['combined_text'] = subset_data[important_columns].apply(flatten_and_combine, axis=1)

print(subset_data['combined_text'].head())
# Out:
# 0    Appliances Refrigerators, Freezers & Ice Maker...
# 1    Appliances Refrigerators, Freezers & Ice Maker...
# 2    Appliances Parts &amp; Accessories The Cigar -...
# 3    Appliances Parts & Accessories Multi purpost d...
# 4    Appliances Parts & Accessories Range Parts & A...
# Name: combined_text, dtype: object

# %%
# Apply the cleaning function to the 'combined_text' column
subset_data['combined_text'] = subset_data['combined_text'].apply(clean_text)

# Validate the cleaned text
print("Cleaned combined text:")
print(subset_data['combined_text'].head())
# Out:
# Cleaned combined text:
# 0    appliances refrigerators freezers  ice makers ...
# 1    appliances refrigerators freezers  ice makers ...
# 2    appliances parts amp accessories the cigar  mo...
# 3    appliances parts  accessories multi purpost de...
# 4    appliances parts  accessories range parts  acc...
# Name: combined_text, dtype: object

# %%
# Specify the filename
text_file_path = 'combined_text.txt'        # all items
# Open the file in write mode and save the content
with open(text_file_path, 'w', encoding='utf-8') as f:
    # Write each row on a new line
    for text in subset_data['combined_text']:
        f.write(text + '\n')

print("Content saved to", text_file_path)
print(subset_data.columns)
# Out:
# Content saved to combined_text.txt
# Index(['category', 'description', 'title', 'brand', 'feature', 'main_cat',
#        'asin', 'combined_text'],
#       dtype='object')

# %%
def clean_text(text):
    # Normalize whitespace
    text = re.sub(r'\s+', ' ', text)

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # Strip HTML content if any
    if '<' in text and '>' in text:
        soup = BeautifulSoup(text, 'html.parser')
        text = soup.get_text(separator=' ', strip=True)

    # Convert to lower case and strip extra spaces
    return text.lower().strip()

# %%
def flatten_and_combine_target(row):
    flattened_elements = []
    for col in row:
        if isinstance(col, list):
            if col:  # Ensure it's not empty
                combined_list_text = ' '.join(str(x) for x in col)
                cleaned_text = clean_text(combined_list_text)  # Clean each combined list text
                flattened_elements.append(cleaned_text)
        elif isinstance(col, str):
            if col.strip():  # Ensure it's not empty
                cleaned_text = clean_text(col)  # Clean each text element
                flattened_elements.append(cleaned_text)

    # Join all non-empty and cleaned elements into a single string
    combined_text = ' '.join(flattened_elements).strip()  # Remove extra spaces
    return combined_text

# %%
# Define the relevant columns for combining text
important_columns = ['category', 'description', 'title', 'brand', 'feature', 'main_cat']

# Apply the flatten-and-combine function to the target item
cleaned_target_text = flatten_and_combine_target(target_item[important_columns].iloc[0])


print("Cleaned text for the target item:")
print(cleaned_target_text)
# Out:
# Cleaned text for the target item:
# appliances parts & accessories refrigerator parts & accessories water filters meet waterdrop advanced n sf 53 certified for health effects y our needs, our priority water quality varies greatly from one region to another. also, individuals attempting to address specific health issues may require different filtration solutions. in such cases, one ordinary filter may not satisfy your special and demanding needs. therefore, we continuously research and develop innovative technologies to produce filters with different effects, and then launch three series accordingly: waterdrop standard , waterdrop advanced and waterdrop plus , to best suit your filtration needs. we try harder and fight to give you cleaner and healthier water in the most effective way. we believe drinking clean water is the basic human rights, so we are committed to delivering clean water to everyone. together with the water project, we are investing in better sanitation in schools in africa to offer children a better future. every time you buy one filter, one child will get one day supply of clean water. till now, thousands of students and families are benefiting from this project, enjoying clean and safe water. - nsf 53 & 42 certified: waterdrop advanced lt800p filters are tested and certified by nsf international against nsf 53 for the reduction of h ealth-related contaminants including lead, cyst, benzene, carbofuran and endrin, and against nsf 42 for aesthetic effects by reducing chlorine, taste and odor. - lead free m ater ial: the filters are tested and certified by nsf international against nsf 372 for lead free. - compatible refrigerator water filter models : lt800p, lt800pc, 9490, 469490, 46-9490, 4609490000, adq73613401, adq73613402, adq32617801, adq73613403, adq32617703, adq73613401-s - compatible refrigerator models : lmxc23746d, lmxc23746s, lmxs30746s, lmxs30756s, lmxs30776d, lmxs30776s, lmxs30786s, lnxc23726s, lnxc23766d, lnxs30866d, lpxs30866d, lpxs30866s, lpxs30876d, lsc22991st, lsxc22326s, lsxc22336s, lsxc22386d, lsxc22386s, lsxs22423b, lsxs22423s, lsxs22423w, lsxs26326b, lsxs26326s, lsxs26326w, lsxs26336v , lsxs26366d, lsxs26366s, lsxs26386d, lsxs26386s, lsxs26466d, lsxs26466s, lupxc2386n, lupxs3186n , lmxs30776, lmxc24746s, lsxs27466 waterdrop nsf 53&amp;42 certified refrigerator water filter, compatible with lg lt800p, adq73613401, kenmore 9490, 46-9490, 469490, adq73613402, advanced, pack of 3 waterdrop nsf 53 certified: reduces specific health-related contaminants for cleaner water: 99.6% of lead, 99.99% of cyst, 96.6% of benzene, 98.4% of carbofuran, 96.6% of endrin nsf 42 certified: reduces 97% of chlorine, taste and odor for great-tasting water that stimulates your palate nsf 372 certified: made of lead-free material for worry-free drinking experience replacement models: lg lt800p, adq73613401, kenmore 9490, 46-9490, 469490, adq73613402. icepure rwf3500a, tier1 rwf1160, clearwater filters cwmf042, denali pure wf-lt800p, dista dwf-35, best choice water filters bcf80. this is an independent brand. replacement models: lsxs26326s, lmxc23746s, lmxc23746d, lsxs26366s, lmxs30776, lmxs30776s, lsxs22423s, lsxs26386d twist and lock design: simple design for easy, tool-free, no-mess filter replacement risk-free guarantee: professional customer service team stands by for your any question in a timely manner eco-friendly material: made from renewable activated coconut carbon filter media for a sustainable world filter life: designed to provide up to 6 months or 300 gallons of refreshing water leak-free fit: precision engineered for perfect fit without water leaks save 10% on waterdrop nsf 401&53&42 lt800p 2 pack when you purchase 1 or more waterdrop nsf 53&42 lt800p 3 pack offered by waterdropdirect. enter code vgqpkx97 at checkout. here's how (restrictions apply) add both to cart save 10% on this item when you purchase 1 or more waterdrop nsf42 lt800p 6 pack offered by waterdropdirect. enter code zgyfez8p at checkout. here's how (restrictions apply)  ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Vectorizer to convert text into numerical representation using TF-IDF
tfidf_vectorizer = TfidfVectorizer(lowercase=True, stop_words='english')
# Transform the combined text of the subset
tfidf_subset = tfidf_vectorizer.fit_transform(subset_data['combined_text'])
# Transform the combined text of the target item
tfidf_target = tfidf_vectorizer.transform([cleaned_target_text])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Compute cosine similarity between the target item and the subset
cosine_sim = cosine_similarity(tfidf_target, tfidf_subset)

# Get the similarity scores
similarity_scores = list(enumerate(cosine_sim[0]))  # Extract the first row of similarity scores

# Sort by similarity score in descending order
sorted_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

# Get the top 5000 most similar items
top_similar_items = [subset_data['asin'].iloc[i[0]] for i in sorted_scores[:5000]]

print("Top 10 most similar items to the target item:")
for item in top_similar_items[:10]:
    print("ASIN:", item)
# Out:
# Top 10 most similar items to the target item:
# ASIN: B01CC7LSEA
# ASIN: B01CC7LSF4
# ASIN: B01CC7LSE0
# ASIN: B01CC7N5PU
# ASIN: B01CC7IVF4
# ASIN: B01CC7N5PA
# ASIN: B01CA3KOA0
# ASIN: B01CA34OU6
# ASIN: B01CA26LYE
# ASIN: B01CC83YAK

# %%
# List of top similar ASINs
top_similar_asins = top_similar_items

# Step 1: Find indices for each ASIN
top_texts = []
asin_found = []  # This will store the ASINs for which text is successfully retrieved
for asin in top_similar_asins:
    if asin in subset_data['asin'].values:
        text = subset_data.loc[subset_data['asin'] == asin, 'combined_text'].values[0]
        top_texts.append(text)
        asin_found.append(asin)
    else:
        print(f"ASIN not found: {asin}")

# %%
Dive_measure_text = [cleaned_target_text] + top_texts[:2000]

# Initialize the vectorizer and fit on all texts to create a consistent vocabulary
tfidf_vectorizer = TfidfVectorizer()
tfidf_all_texts = tfidf_vectorizer.fit_transform(Dive_measure_text)

# Separate the target's TF-IDF vector and similar items' TF-IDF vectors
tfidf_target = tfidf_all_texts[0]  # Target text is the first one
tfidf_similars = tfidf_all_texts[1:]  # Rest are the similar items

# %%
from scipy.spatial.distance import euclidean

# %%
array_target = tfidf_target.toarray()  # Convert to dense format if feasible
array_similars = tfidf_similars.toarray()

# Function to calculate Euclidean distances
def calculate_euclidean_distances(target, similars):
    distances = []
    # Ensure the target is a 1-D array
    target = target.flatten()  # This makes sure the target is 1-D if it isn't already
    for similar in similars:
        # Ensure each similar item vector is also 1-D
        similar = similar.flatten()  # Flatten the similar array to be 1-D
        dist = euclidean(target, similar)
        distances.append(dist)
    return distances

# %%
# Assuming that array_target and array_similars have been defined correctly
# Calculate Euclidean distances from the target to each similar item
# Here we assume array_target is already 2D but only contains one row (one target vector)
euclidean_distances = calculate_euclidean_distances(array_target[0], array_similars)

# %%
# Pair each ASIN with its Jaccard distance and sort by distance
asin_distances = list(zip(asin_found, euclidean_distances))
asin_distances_sorted = sorted(asin_distances, key=lambda x: x[1], reverse=True)

# Print the top 10 most diverse ASIN with its corresponding Jaccard distance
for asin, distance in asin_distances_sorted[:10]:
    print(f"ASIN: {asin}, euclidean Distance: {distance}")
# Out:
# ASIN: B000UVYJHE, euclidean Distance: 1.4010019935917075
# ASIN: B014W61VNM, euclidean Distance: 1.3986397755661921
# ASIN: B00FYWKT28, euclidean Distance: 1.3984273458463816
# ASIN: B015WVQWNK, euclidean Distance: 1.3980481306699835
# ASIN: B004E6UV7S, euclidean Distance: 1.3980174791535016
# ASIN: B00M4GFHY2, euclidean Distance: 1.3978939542667297
# ASIN: B00WA1A14M, euclidean Distance: 1.3977589921831517
# ASIN: B0074CJFVC, euclidean Distance: 1.3976911924624293
# ASIN: B00EXRIMRO, euclidean Distance: 1.3974072447944506
# ASIN: B002HXZFB2, euclidean Distance: 1.397358296467105

# %%
import numpy as np

# %%
def calculate_miuf(bundle, user_item_matrix):   
    # Initialize a list to store the inverse user frequencies of the items in the bundle
    iuf_values = []
    
    # Calculate the total number of users
    total_users = user_item_matrix.shape[0]

    # For each item in the bundle
    for asin in bundle:
        # Calculate the user frequency of the item (i.e., the number of users who have interacted with the item)
        user_frequency = user_item_matrix.get(asin, np.array([1])).sum()

        # Calculate the inverse user frequency of the item
        iuf = -np.log2(user_frequency / total_users)
        
        # Add the inverse user frequency to the list
        iuf_values.append(iuf)

    # Calculate the MIUF of the bundle (i.e., the mean of the inverse user frequencies)
    miuf = np.mean(iuf_values)
    
    # Return the MIUF of bundle
    return iuf_values, miuf

# %%
def calculate_iuf(user_frequency, total_users):
    # Calculate the Inverse User Frequency (IUF) for a single item.
    
    # Prevent division by zero by ensuring user_frequency is at least 1
    user_frequency = max(user_frequency, 1)
    
    # Calculate the inverse user frequency
    iuf = -np.log2(user_frequency / total_users)
    return iuf

def calculate_miuf_for_all_items(user_item_matrix):
    """
    Calculate the MIUF for all items in the dataset.
    
    Parameters:
    - user_item_matrix: a dictionary where keys are item ASINs and values are 
      arrays representing user interactions (1 if user interacted, 0 if not).
      
    Returns:
    - miuf_values: a dictionary where keys are item ASINs and values are the MIUF values.
    """
    
    # Initialize a dictionary to store the MIUF for each item
    miuf_values = {}
    
    # Calculate the total number of users
    total_users = user_item_matrix.shape[0]
    
    # Iterate over each item in the dataset
    for asin in user_item_matrix.columns:
        # Calculate the user frequency of the item
        user_frequency = user_item_matrix[asin].sum()
        
        # Calculate the inverse user frequency (IUF) of the item
        iuf = calculate_iuf(user_frequency, total_users)
        
        # Store the IUF value for this item
        miuf_values[asin] = iuf
        
    return miuf_values

# Example usage:
# Assuming user_item_matrix is a DataFrame where each row is a user and each column is an item (ASIN).
# For example, user_item_matrix.loc[user_id, asin] == 1 if the user interacted with the item, else 0.
miuf_values = calculate_miuf_for_all_items(user_item_matrix)

# Now miuf_values is a dictionary containing the MIUF for each item in the dataset

# Assuming miuf_values is a dictionary where keys are ASINs and values are MIUF scores
miuf_list = list(miuf_values.values())

# Plot the histogram of MIUF values
plt.figure(figsize=(10, 6))
plt.hist(miuf_list, bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of MIUF Values')
plt.xlabel('MIUF Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Calculate specific percentiles
percentile_90 = np.percentile(miuf_list, 90)
percentile_75 = np.percentile(miuf_list, 75)

print(f"90th Percentile MIUF: {percentile_90}")
print(f"75th Percentile MIUF: {percentile_75}")
# Out:
# 90th Percentile MIUF: 12.797486520310073
# 75th Percentile MIUF: 12.449563216889766

# %%
def get_user_previous_interactions(user_id):
    # Filter the DataFrame to include only interactions from the specified user
    user_interactions = df_copy[df_copy['user_id'] == user_id]
    
    # Sort the interactions by timestamp or time, depending on what's available
    if 'timestamp' in user_interactions.columns:
        user_interactions = user_interactions.sort_values(by='timestamp', ascending=False)
    elif 'time' in user_interactions.columns:
        user_interactions = user_interactions.sort_values(by='time', ascending=False)
    
    # Get the most recent n interactions (ASINs)
    user_previous_asins = user_interactions['asin'].head(len(user_interactions)).tolist()
    
    return user_previous_asins

# %%
# Retrieve user's previously interacted items
user_previous_items = get_user_previous_interactions(user_id)

# %%
def calculate_unexpectedness(bundle):
    distances = []
    
    # Convert tfidf_matrix to dense format if not already
    dense_tfidf_matrix = tfidf_subset.toarray()

    # Map ASINs to their indices in the subset_data DataFrame
    asin_to_index = {asin: i for i, asin in enumerate(subset_data['asin'])}
    
    for recommended_asin in bundle:
        if recommended_asin in asin_to_index:
            rec_index = asin_to_index[recommended_asin]
            rec_vector = dense_tfidf_matrix[rec_index].reshape(1, -1) 
            
            for interacted_asin in user_previous_items:
                if interacted_asin in asin_to_index:
                    int_index = asin_to_index[interacted_asin]
                    int_vector = dense_tfidf_matrix[int_index].reshape(1, -1)
                    
                    # Compute the cosine similarity
                    similarity = cosine_similarity(rec_vector, int_vector)[0][0]
                    
                    # Convert similarity to distance (cosine distance = 1 - cosine similarity)
                    distance = 1 - similarity
                    distances.append(distance)
    
    # Return the average distance (Unexpectedness)
    return np.mean(distances) if distances else 0

# %%
number_of_bundles = 10
bundles_wo_diversity = []
for i in range(number_of_bundles):
    bundles_wo_diversity.append(top_similar_asins[i * 5:(i+1) * 5])

avg_mean_pred_ratings_0 = []
avg_var_pred_ratings_0 = []
avg_miuf_0 = []
bundle_info = []

for i, bundle in enumerate(bundles_wo_diversity):
    pred_ratings = []
    for asin in bundle:
        pred_rating = algorithm.predict(user_id, asin).est
        pred_ratings.append(pred_rating)
    
    avg_pred_rating = np.mean(pred_ratings)
    avg_mean_pred_ratings_0.append(avg_pred_rating)
    
    var_pred_rating = np.var(pred_ratings)
    avg_var_pred_ratings_0.append(var_pred_rating)
    
    iuf, miuf = calculate_miuf(bundle, user_item_matrix)
    avg_miuf_0.append(miuf)
    
    unexpectedness = calculate_unexpectedness(bundle)
    
    bundle_info.append([bundle, avg_pred_rating, var_pred_rating, miuf, iuf, unexpectedness])

# %%
def form_bundle(target_vector, tfidf_matrix, top_similar_items, subset_data, n=5, num_bundles=10):
    # Convert the target vector into a dense array if necessary
    target_vector = target_vector.toarray()

    # Convert tfidf_matrix to dense format if not already
    dense_tfidf_matrix = tfidf_matrix.toarray()

    # Map ASINs to their indices in the subset_data DataFrame
    asin_to_index = {asin: i for i, asin in enumerate(subset_data['asin'])}
    top_similar_indices = [asin_to_index[asin] for asin in top_similar_items if asin in asin_to_index]

    # Initialize the bundle with the index of the most similar item
    bundle_indices = [top_similar_indices[0]]  # Start with the most similar item
    remaining_indices = top_similar_indices[1:]  # Remaining items to choose from

    bundles = []
    for _ in range(num_bundles):
        # Initialize the bundle with the index of the most similar item
        bundle_indices = [top_similar_indices.pop(0)]  # Start with the most similar item

        # Keep adding items to the bundle until we reach the desired number or run out of items
        while len(bundle_indices) < n and top_similar_indices:
            last_added_idx = bundle_indices[-1]
            last_added_vector = dense_tfidf_matrix[last_added_idx]

            # Calculate Euclidean distances from the last added item to all remaining candidates
            distances = [euclidean(last_added_vector, dense_tfidf_matrix[idx]) for idx in top_similar_indices]

            # Find the index of the item with the maximum distance
            max_distance_idx = np.argmax(distances)

            # Add this item to the bundle
            bundle_indices.append(top_similar_indices.pop(max_distance_idx))

        # Add the bundle to the list of bundles
        bundles.append([subset_data['asin'].iloc[idx] for idx in bundle_indices])

    # Return the ASINs of the items in the bundle
    return bundles

# %%
# Use the function with the DataFrame included
bundle_asins = form_bundle(tfidf_target, tfidf_subset, top_similar_items, subset_data)

avg_mean_pred_ratings_1 = []
avg_var_pred_ratings_1 = []
avg_miuf_1 = []
bundle_info_1 = []

for i, bundle in enumerate(bundle_asins):
    pred_ratings = []
    for asin in bundle:
        pred_rating = algorithm.predict(user_id, asin).est
        pred_ratings.append(pred_rating)
    
    avg_pred_rating = np.mean(pred_ratings)
    avg_mean_pred_ratings_1.append(avg_pred_rating)
    
    var_pred_rating = np.var(pred_ratings)
    avg_var_pred_ratings_1.append(var_pred_rating)
    
    iuf, miuf = calculate_miuf(bundle, user_item_matrix)
    avg_miuf_1.append(miuf)
    
    unexpectedness = calculate_unexpectedness(bundle)
    
    bundle_info_1.append([bundle, avg_pred_rating, var_pred_rating, miuf, iuf, unexpectedness])

# %%
# Create a copy of the sorted distances
asin_distances_sorted_copy = asin_distances_sorted.copy()

# Shuffle the data
random.shuffle(asin_distances_sorted_copy)

# Initialize an empty list to hold the bundles
bundles = []

# For each bundle
for b in range(10):
    # If it's the first bundle
    if b == 0:
        # Use 4 partitions
        num_partitions = 4
    else:
        # Use 5 partitions for the second and third bundles
        num_partitions = 5

    # Determine the number of items per partition
    num_items = len(asin_distances_sorted_copy)
    items_per_partition = (num_items + num_partitions - 1) // num_partitions

    # Create partitions
    partitions = [asin_distances_sorted_copy[i:i + items_per_partition] for i in range(0, num_items, items_per_partition)]

    # Ensure that there are exactly num_partitions partitions
    while len(partitions) > num_partitions:
        last_items = partitions.pop()  # Remove last partition
        # Distribute last_items back into the other partitions
        for i, item in enumerate(last_items):
            partitions[i % num_partitions].append(item)

    # Select one ASIN randomly from each partition
    selected_asins = [np.random.choice([item[0] for item in partition]) for partition in partitions if partition]

    # Remove the selected ASINs from the asin_distances_sorted_copy list
    for asin in selected_asins:
        asin_distances_sorted_copy = [item for item in asin_distances_sorted_copy if item[0] != asin]

    # If it's the first bundle
    if b == 0:
        # Include the target ASIN at the beginning of the bundle
        bundle = [target_asin] + selected_asins
    else:
        # Include all selected ASINs in the bundle
        bundle = selected_asins

    # Add the bundle to the bundles list
    bundles.append(bundle)
    
avg_mean_pred_ratings_2 = []
avg_var_pred_ratings_2 = []
avg_miuf_2 = []
bundle_info_2 = []
for i, bundle in enumerate(bundles):
    pred_ratings = []
    for asin in bundle:
        pred_rating = algorithm.predict(user_id, asin).est
        pred_ratings.append(pred_rating)
    
    avg_pred_rating = np.mean(pred_ratings)
    avg_mean_pred_ratings_2.append(avg_pred_rating)
    
    var_pred_rating = np.var(pred_ratings)
    avg_var_pred_ratings_2.append(var_pred_rating)
    
    iuf, miuf = calculate_miuf(bundle, user_item_matrix)
    avg_miuf_2.append(miuf)
    
    unexpectedness = calculate_unexpectedness(bundle)
    
    bundle_info_2.append([bundle, avg_pred_rating, var_pred_rating, miuf, iuf, unexpectedness])

# %%
bundle_data = [
    {
        "method": "without diversity", 
        "average_predicted_rating": avg_mean_pred_ratings_0,
        "variance_predicted_rating": avg_var_pred_ratings_0,
        "miuf": avg_miuf_0
    },
    {
        "method": "bundle function", 
        "average_predicted_rating": avg_mean_pred_ratings_1,
        "variance_predicted_rating": avg_var_pred_ratings_1,
        "miuf": avg_miuf_1
    },
    {
        "method": "bundle partition", 
        "average_predicted_rating": avg_mean_pred_ratings_2,
        "variance_predicted_rating": avg_var_pred_ratings_2,
        "miuf": avg_miuf_2
    }
]

# %%
def ILD(bundle, tfidf_matrix, subset_data):
    # Map ASINs to their indices in the subset_data DataFrame
    asin_to_index = {asin: i for i, asin in enumerate(subset_data['asin'])}
    
    # Get the indices of the items in the bundle
    indices = [asin_to_index[asin] for asin in bundle]
    
    # Get the tf-idf vectors of the items
    vectors = tfidf_matrix[indices]
    
    # Calculate the pairwise cosine similarities
    similarities = cosine_similarity(vectors)
    
    # Calculate the pairwise distances
    distances = 1 - similarities
    
    # Calculate the ILD as the average of the pairwise distances
    ILD = np.sum(distances) / (len(bundle) * (len(bundle) - 1))
    
    return ILD

# %%
ilds_0 = [ILD(bundle, tfidf_subset, subset_data) for bundle in bundles_wo_diversity]
ilds_1 = [ILD(bundle, tfidf_subset, subset_data) for bundle in bundle_asins]
ilds_2 = [ILD(bundle, tfidf_subset, subset_data) for bundle in bundles]

# %%
for i in range(number_of_bundles):
    bundle_info[i].append(ilds_0[i])
    bundle_info_1[i].append(ilds_1[i])
    bundle_info_2[i].append(ilds_2[i])

# %%
# Sort bundles based on the sum of MIUF and average predicted rating
sorted_bundles = sorted(bundle_info, key=lambda x: x[1] + x[5], reverse=True)

# Print sorted bundles
for i, (bundle, avg_pred_rating, var_pred_rating, miuf, iuf, ild, uxp) in enumerate(sorted_bundles):
    print(f'Bundle {i + 1}:')
    for asin in bundle:
        asin_meta = metadata.loc[metadata['asin'] == asin].reset_index(drop=True)
        print(f"- {asin}: {asin_meta.loc[0, 'title']}, Predicted Rating: {algorithm.predict(user_id, asin).est}")
    
    print('-' * 25)
    print(f'Bundle Average Predicted Rating: {avg_pred_rating}')
    print(f'Bundle Variance of Predicted Rating: {var_pred_rating}')
    print(f'Bundle IUF: {iuf}')
    print(f'Bundle MIUF: {miuf}')
    print(f'Bundle ILD: {ild}')
    print(f'Bundle Unexpectedness: {uxp}')
    print('-' * 25)
# Out:
# Bundle 1:
# - B01CA411SI: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT500P, 5231JA2002A, ADQ72910901, Kenmore GEN11042FR-08, 9890, 46-9890, Advanced Series, Pack of 3, Predicted Rating: 4.814802586775422
# - B01CC7SBC2: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE RPWF(Not RPWFE), Advanced, Pack of 2, Predicted Rating: 4.8396726628179545
# - B01GAAYTGY: Waterdrop NSF 401&amp;53&amp;42 Certified DA29-00020B Replacement Refrigerator Water Filter, Compatible with Samsung DA29-00020B, DA29-00020A, HAF-CIN/EXP, 46-9101, Plus, Pack of 3, Predicted Rating: 4.566686812209036
# - B01CC7IVKY: Waterdrop Refrigerator Water Filter, Compatible with LG LT700P, ADQ36006101, KENMORE 469690, 9690, ADQ36006102, Standard, Predicted Rating: 4.144548716592425
# - B01CC7O8LA: Waterdrop MWF NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE MWF, MWFP, MWFA, GWF, GWFA, SmartWater, Kenmore 9991, 46-9991, 469991, Advanced, Pack of 2, Predicted Rating: 4.903743078406397
# -------------------------
# Bundle Average Predicted Rating: 4.653890771360247
# Bundle Variance of Predicted Rating: 0.07797351162336957
# Bundle IUF: [11.212524019588917, 11.86460071616861, 11.20163570344618, 11.137977066223863, 10.356051330966622]
# Bundle MIUF: 11.154557767278838
# Bundle ILD: 0.9874093557591687
# Bundle Unexpectedness: 0.2985700307844671
# -------------------------
# Bundle 2:
# - B01CC7LSEA: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, Kenmore 9490, 46-9490, 469490, ADQ73613402, Advanced, Pack of 3, Predicted Rating: 5
# - B01CC7LSF4: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, Kenmore 9490, 46-9490, 469490, ADQ73613402, Advanced, Pack of 2, Predicted Rating: 4.508104384787424
# - B01CC7LSE0: Waterdrop Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, Kenmore 9490, 46-9490, 469490, ADQ73613402, Standard, Predicted Rating: 4.08909226416551
# - B01CC7N5PU: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE MSWF, 101820A, 101821B, 101821-B, Advanced , Pack of 3, Predicted Rating: 4.362872014280058
# - B01CC7IVF4: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT700P, ADQ36006101, KENMORE 469690, 9690, ADQ36006102, Advanced, Pack of 3, Predicted Rating: 4.507637141229911
# -------------------------
# Bundle Average Predicted Rating: 4.493541160892581
# Bundle Variance of Predicted Rating: 0.08751293516042127
# Bundle IUF: [10.356051330966622, 11.781184707980973, 11.04746477331842, 11.411428088002994, 10.037749618485208]
# Bundle MIUF: 10.926775703750844
# Bundle ILD: 0.9888880399349553
# Bundle Unexpectedness: 0.17487819941764163
# -------------------------
# Bundle 3:
# - B01CC83Y96: Waterdrop UKF8001 NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with Maytag UKF8001, UKF8001AXX, Whirlpool 4396395, 469006, EveryDrop Filter 4, Puriclean II, Pack of 2, Predicted Rating: 4.141310060638438
# - B01CC7SBE0: Waterdrop Refrigerator Water Filter, Compatible with GE RPWF(Not RPWFE), Standard, Predicted Rating: 4.23581912375556
# - B01CA40YFY: Waterdrop Refrigerator Water Filter, Compatible with LG LT500P, 5231JA2002A, ADQ72910901, Kenmore GEN11042FR-08, 9890, 46-9890, Predicted Rating: 4.78497936947437
# - B01CC7IVD6: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT700P, ADQ36006101, KENMORE 469690, 9690, ADQ36006102, Advanced, Pack of 2, Predicted Rating: 4.284317445788649
# - B01CA26M2A: Waterdrop DA29-00003G Replacement Refrigerator Water Filter, Compatible with Samsung DA29-00003G, Aqua-Pure Plus DA29-00003B, HAFCU1, DA29-00003A, Standard, Predicted Rating: 4.949551322045954
# -------------------------
# Bundle Average Predicted Rating: 4.479195464340594
# Bundle Variance of Predicted Rating: 0.1052228921645741
# Bundle IUF: [9.456018239027065, 11.613061949172646, 10.405169097531312, 11.657005296760243, 10.032916464749265]
# Bundle MIUF: 10.632834209448106
# Bundle ILD: 0.9867214051223826
# Bundle Unexpectedness: 0.3120348970098955
# -------------------------
# Bundle 4:
# - B01CC7O8JW: Waterdrop MWF Refrigerator Water Filter, Compatible with GE MWF, MWFP, MWFA, GWF, GWFA, SmartWater, Kenmore 9991, 46-9991, 469991, Standard, Predicted Rating: 4.4678356163287685
# - B01CA410KW: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT500P, 5231JA2002A, ADQ72910901, Kenmore GEN11042FR-08, 9890, 46-9890, Advanced Series, Pack of 2, Predicted Rating: 4.623544760496367
# - B01G4XRSXI: AQUACREST Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, ADQ73613402, Kenmore 9490, 46-9490, Predicted Rating: 4.02624624581063
# - B01C9X8OLM: Waterdrop NSF 53&amp;42 Certified 4396508 Replacement Refrigerator Water Filter, Compatible with Whirlpool 4396508, 4396510, Kenmore 46-9010, EveryDrop Filter 5, NLC240V, EDR5RXD1, PUR W10186668, 3 Pack, Predicted Rating: 4.617401418483915
# - B01CC7SBAY: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE RPWF(Not RPWFE), Advanced, Pack of 3, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 4.317970828764602
# Bundle Variance of Predicted Rating: 0.10101996598867206
# Bundle IUF: [8.327659730310398, 10.456018239027065, 13.008990625503785, 11.234550325918915, 18.25691813894737]
# Bundle MIUF: 12.256827411941506
# Bundle ILD: 0.9856872440639519
# Bundle Unexpectedness: 0.528685227062798
# -------------------------
# Bundle 5:
# - B01CC7N5PA: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE MSWF, 101820A, 101821B, 101821-B, Advanced, Pack of 2, Predicted Rating: 4.366610793641823
# - B01CA3KOA0: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE GSWF SmartWater 238C2334P001, Kenmore 46-9914, 469914, 9914, Advanced, Pack of 3, Predicted Rating: 3.9041295681229355
# - B01CA34OU6: Waterdrop NSF 53&amp;42 Certified DA29-00020B Refrigerator Water Filter, Compatible with Samsung DA29-00020B, DA29-00020A, HAF-CIN/EXP, 46-9101, Advanced, Pack of 3, Predicted Rating: 4.115751869779694
# - B01CA26LYE: Waterdrop NSF 53&amp;42 Certified DA29-00003G Refrigerator Water Filter, Compatible with Samsung DA29-00003G, Aqua-Pure Plus DA29-00003B, HAFCU1, DA29-00003A, Advanced, Pack of 3, Predicted Rating: 4.548348314395621
# - B01CC83YAK: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with Maytag UKF8001, UKF8001AXX, Whirlpool 4396395, 469006, EveryDrop Filter 4, Puriclean II, Pack of 3, Predicted Rating: 4.4037541635923265
# -------------------------
# Bundle Average Predicted Rating: 4.26771894190648
# Bundle Variance of Predicted Rating: 0.0524658496643019
# Bundle IUF: [11.09704680216898, 12.398937143819797, 8.436739176532182, 9.50872528935791, 9.741218300663327]
# Bundle MIUF: 10.236533342508439
# Bundle ILD: 0.9870908738051309
# Bundle Unexpectedness: 0.21848719234874486
# -------------------------
# Bundle 6:
# - B01CA0V1T6: Waterdrop Refrigerator Water Filter, Compatible with Whirlpool 8171413, 8171414, EDR8D1, Kenmore 46-9002, Pack of 2, Predicted Rating: 3.9658792688788274
# - B01G50KNJQ: AQUACREST Refrigerator Water Filter, Compatible with LG LT700P, Kenmore 9690, 46-9690, ADQ36006101, ADQ36006102 (Pack of 3), Predicted Rating: 4.542115922170005
# - B01G50P7AQ: AQUACREST Refrigerator Water Filter, Compatible with LG LT700P, Kenmore 9690, 46-9690, ADQ36006101, ADQ36006102 (Pack of 6), Predicted Rating: 3.854826102703327
# - B01G3X096W: AQUACREST Replacement RPWF Refrigerator Water Filter, Compatible with GE RPWF (Pack of 3) (NOT RPWFE), Predicted Rating: 3.854826102703327
# - B01CC7UI46: Waterdrop Refrigerator Water Filter, Compatible with Maytag UKF7003, UKF7002AXX, UKF7002, UKF7003AXX, 7003AXXP, UKF7001AXX, UKF6001AXX, UKF5001AXX, Whirlpool EDR7D1, Pack of 3, Predicted Rating: 5
# -------------------------
# Bundle Average Predicted Rating: 4.243529479291097
# Bundle Variance of Predicted Rating: 0.20813435637122474
# Bundle IUF: [10.657005296760243, 12.212524019588917, 18.25691813894737, 18.25691813894737, 12.350027543338852]
# Bundle MIUF: 14.34667862751655
# Bundle ILD: 0.9810329272120759
# Bundle Unexpectedness: 0.32967786267243293
# -------------------------
# Bundle 7:
# - B01GABJMQ0: Waterdrop NSF 401&amp;53&amp;42 Certified DA29-00003G Refrigerator Water Filter, Compatible with Samsung DA29-00003G, Aqua-Pure Plus DA29-00003B, HAFCU1, DA29-00003A, Plus, Pack of 1, Predicted Rating: 4.385629754957091
# - B01ETBOOLG: AQUACREST Replacement GXRLQR Inline Water Filter, Compatible with GE SmartWater Twist Lock In-Line GXRLQR Water Filter, Predicted Rating: 3.5774737647279156
# - B01CA3KMUW: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE GSWF SmartWater 238C2334P001, Kenmore 46-9914, 469914, 9914, Advanced, Pack of 2, Predicted Rating: 3.854826102703327
# - B01CC7UIH8: Waterdrop Refrigerator Water Filter, Compatible with Maytag UKF7003, UKF7002AXX, UKF7002, UKF7003AXX, 7003AXXP, UKF7001AXX, UKF6001AXX, UKF5001AXX, Whirlpool EDR7D1, Predicted Rating: 4.596751843682388
# - B01GAAJJ6O: Waterdrop UKF8001 NSF 401&amp;53&amp;42 Certified Refrigerator Water Filter, Compatible with Maytag UKF8001, UKF8001AXX, UKF8001P, Whirlpool 4396395, 469006, Filter 4, Puriclean II, Pack of 2, Predicted Rating: 4.735901095268539
# -------------------------
# Bundle Average Predicted Rating: 4.230116512267852
# Bundle Variance of Predicted Rating: 0.19624186534438684
# Bundle IUF: [12.797486520310073, 12.04746477331842, 18.25691813894737, 10.881878707600444, 11.570417611764151]
# Bundle MIUF: 13.110833150388093
# Bundle ILD: 0.9835280531114803
# Bundle Unexpectedness: 0.5130283366463076
# -------------------------
# Bundle 8:
# - B01G4W95US: AQUACREST Replacement MWF Refrigerator Water Filter, Compatible with GE MWF SmartWater, MWFA, MWFP, GWF, GWFA, 46-9991, HDX FMG-1, WFC1201, GSE25GSHECSS, PC75009, RWF1060, 197D6321P006 (Pack of 6), Predicted Rating: 3.854826102703327
# - B01G4W95VC: AQUACREST Replacement MWF Refrigerator Water Filter, Compatible with GE MWF SmartWater, MWFA, MWFP, GWF, GWFA, 46-9991, HDX FMG-1, WFC1201, GSE25GSHECSS, PC75009, RWF1060 (Pack of 3), Predicted Rating: 4.386826370502572
# - B01CA34OZG: Waterdrop NSF 53&amp;42 Certified DA29-00020B Refrigerator Water Filter, Compatible with Samsung DA29-00020B, DA29-00020A, HAF-CIN/EXP, 46-9101, Advanced, Pack of 2, Predicted Rating: 4.135826975352096
# - B01G4Y5M1C: AQUACREST Replacement MSWF Refrigerator Water Filter, Compatible with GE MSWF SmartWater 101821B 101820A (Pack of 3), Predicted Rating: 4.528152608481768
# - B01CA1V5NM: Waterdrop Refrigerator Water Filter, Compatible with 3M Cuno CS-52, CS-51, CS-452, CS-522, CS-532, CS-562, CS450, CS-512, W1085590, 56932, 2168701, 51000, 52000, Pack of 2, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 4.152091631948618
# Bundle Variance of Predicted Rating: 0.07470407687284561
# Bundle IUF: [18.25691813894737, 10.47555842542271, 9.158886055986843, 11.917068136062746, 18.25691813894737]
# Bundle MIUF: 13.613069779073408
# Bundle ILD: 0.98598608709862
# Bundle Unexpectedness: 0.5303037116683459
# -------------------------
# Bundle 9:
# - B01G4XRT1E: AQUACREST Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, ADQ73613402, Kenmore 9490, 46-9490 (Pack of 6), Predicted Rating: 3.854826102703327
# - B01C9WG9DI: Waterdrop 4396508 NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with Whirlpool 4396508, 4396510, Kenmore 46-9010, EveryDrop Filter 5, NLC240V, EDR5RXD1, PUR W10186668, Pack of 2, Predicted Rating: 4.331413477821315
# - B01FQMDZ7Q: Waterdrop DA29-00020B Refrigerator Water Filter, Compatible with Samsung DA29-00020B, DA29-00020A, HAF-CIN/EXP, 46-9101, Standard, Pack of 6, Predicted Rating: 4.75736607418261
# - B01GAAJJ6Y: Waterdrop UKF8001 NSF 401&amp;53&amp;42 Certified Refrigerator Water Filter, Compatible with Maytag UKF8001, UKF8001AXX, UKF8001P, Whirlpool 4396395, 469006, Filter 4, Puriclean II, Pack of 3, Predicted Rating: 3.854826102703327
# - B01GADB068: Waterdrop NSF 401&amp;53&amp;42 Certified Refrigerator Water Filter, Compatible with GE RPWF(Not RPWFE), Pack of 2, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 4.130651572022781
# Bundle Variance of Predicted Rating: 0.13226309572263859
# Bundle IUF: [18.25691813894737, 10.143175972898181, 10.620293518403722, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 15.106844781628803
# Bundle ILD: 0.9845390517237689
# Bundle Unexpectedness: 0.46579187532787864
# -------------------------
# Bundle 10:
# - B01G4S8VDY: AQUACREST Refrigerator Water Filter, Compatible with LG 5231JA2002A, LT500P, GEN11042FR-08, LFX25974ST, ADQ72910901, ADQ72910907, Kenmore 9890, 46-9890, 469890 (Pack of 3), Predicted Rating: 4.5263483204962345
# - B01G4RZ2WI: AQUACREST Refrigerator Water Filter, Compatible with LG 5231JA2002A, LT500P, GEN11042FR-08, LFX25974ST, ADQ72910901, ADQ72910907, Kenmore 9890, 46-9890, 469890 (Pack of 2), Predicted Rating: 3.854826102703327
# - B01CC7GT1C: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT600P, 5231JA2006A, 5231JA2006B, KENMORE 46-9990, 9990, 469990, Advanced, Pack of 2, Predicted Rating: 4.0580950973947045
# - B01CA0NP4K: Waterdrop Refrigerator Water Filter, Compatible with Bosch Ultra Clarity 644845, 9000077104, 9000194412, Haier 0060820860, 0060218744, Miele KWF1000, Predicted Rating: 3.854826102703327
# - B01CC7N5NC: Waterdrop Refrigerator Water Filter, Compatible with GE MSWF, 101820A, 101821B, 101821-B-Standard, Predicted Rating: 4.2799969477038395
# -------------------------
# Bundle Average Predicted Rating: 4.114818514200286
# Bundle Variance of Predicted Rating: 0.06701007009015536
# Bundle IUF: [12.765065042617696, 18.25691813894737, 10.757072251864164, 18.25691813894737, 10.39273199429309]
# Bundle MIUF: 14.085741113333938
# Bundle ILD: 0.9853170108306817
# Bundle Unexpectedness: 0.5464017407588593
# -------------------------

# %%
# Sort bundles based on the sum of MIUF and average predicted rating
sorted_bundles_1 = sorted(bundle_info_1, key=lambda x: x[1] + x[5], reverse=True)

# Print sorted bundles
for i, (bundle, avg_pred_rating, var_pred_rating, miuf, iuf, ild, uxp) in enumerate(sorted_bundles_1):
    print(f'Bundle {i + 1}:')
    for asin in bundle:
        asin_meta = metadata.loc[metadata['asin'] == asin].reset_index(drop=True)
        print(f"- {asin}: {asin_meta.loc[0, 'title']}, Predicted Rating: {algorithm.predict(user_id, asin).est}")
    
    print('-' * 25)
    print(f'Bundle Average Predicted Rating: {avg_pred_rating}')
    print(f'Bundle Variance of Predicted Rating: {var_pred_rating}')
    print(f'Bundle IUF: {iuf}')
    print(f'Bundle MIUF: {miuf}')
    print(f'Bundle ILD: {ild}')
    print(f'Bundle Unexpectedness: {uxp}')
    print('-' * 25)
# Out:
# Bundle 1:
# - B01CC7LSEA: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, Kenmore 9490, 46-9490, 469490, ADQ73613402, Advanced, Pack of 3, Predicted Rating: 5
# - B00C8ULTYG: Kissler &amp; Company Inc. 88-6096 Braided Ice Maker Line, 1/4-Inch Compression by 1/4-Inch Compression, Stainless Steel, Predicted Rating: 3.854826102703327
# - B005FD7ZG4: The Laundry POD, Silver, Predicted Rating: 3.854826102703327
# - B01723LFDI: Humidifier Filter for Holmes HWF75PDQ-U HWF75 (3-Pack), Predicted Rating: 3.854826102703327
# - B019PBHB1K: DELLA Electric Small Mini Portable Compact Washer Washing Machine (33L Washer &amp; 16L Dryer), Predicted Rating: 4.1537006440542
# -------------------------
# Bundle Average Predicted Rating: 4.143635790432837
# Bundle Variance of Predicted Rating: 0.19673881357705258
# Bundle IUF: [10.356051330966622, 18.25691813894737, 18.25691813894737, 18.25691813894737, 11.09704680216898]
# Bundle MIUF: 15.244770509995542
# Bundle ILD: 0.9905324041010479
# Bundle Unexpectedness: 0.9695384634503403
# -------------------------
# Bundle 2:
# - B01CC7IVF4: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT700P, ADQ36006101, KENMORE 469690, 9690, ADQ36006102, Advanced, Pack of 3, Predicted Rating: 4.507637141229911
# - B00NN1TGHQ: DMAFRIGFFET1022QW - Frigidaire 9.9 Cu. Ft. Top Freezer Apartment-Size Refrigerator, Predicted Rating: 3.854826102703327
# - B009XDMEK4: Watts Premier 164020 DLA-D Drain Line Plumbing Adapter, Predicted Rating: 4.417920394613111
# - B004RRDCZW: Fisher Paykel CMOH-30SS Over the Range Microwave, Predicted Rating: 3.854826102703327
# - B009LPJEFM: Purenex 4C-2S-2I-1M75 Cartridges for RO Replacement Water Filters, 9-Pack, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 4.0980071687906
# Bundle Variance of Predicted Rating: 0.08951045581736475
# Bundle IUF: [10.037749618485208, 18.25691813894737, 12.830653384245272, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 15.52783148391452
# Bundle ILD: 0.976673838643747
# Bundle Unexpectedness: 0.9778870715550649
# -------------------------
# Bundle 3:
# - B01CC83YAK: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with Maytag UKF8001, UKF8001AXX, Whirlpool 4396395, 469006, EveryDrop Filter 4, Puriclean II, Pack of 3, Predicted Rating: 4.4037541635923265
# - B00SBTC05U: LG Ultra Large Capacity Top Load Laundry System with Turbo Wash Technology (WT5170HW_DLEX5170W), Predicted Rating: 3.854826102703327
# - B00ZY6KM4E: ICEPURE DA29-00020B Replacement Refrigerator Water Filter, Compatible with Samsung DA29-00020B, DA29-00020A, HAF-CIN/EXP, HAF-CIN, DA97-08006A, Kenmore 469101 [Pack of 3], Predicted Rating: 4.387781887224848
# - B00WZYDGWI: Whirlpool UXT4030ADB 30 Black Recirculating Under-cabinet Hood, Predicted Rating: 3.854826102703327
# - B016NCST2O: 3-Pack Replacement Ultra Clarity Refrigerator Water Filter for Bosch - Compatible with Bosch B26FT70SNS, Bosch B22CS30SNS, Bosch B22CS50SNS, Bosch B22CS80SNS, Bosch B36BT830NS, Bosch B30BB830SS, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 4.071202871785431
# Bundle Variance of Predicted Rating: 0.07025387065885123
# Bundle IUF: [9.741218300663327, 18.25691813894737, 9.830653384245272, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 14.868525220350142
# Bundle ILD: 0.9956293351627359
# Bundle Unexpectedness: 0.9458339986812376
# -------------------------
# Bundle 4:
# - B01CA3KOA0: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE GSWF SmartWater 238C2334P001, Kenmore 46-9914, 469914, 9914, Advanced, Pack of 3, Predicted Rating: 3.9041295681229355
# - B015YORBCQ: EAU37932701, Predicted Rating: 3.854826102703327
# - B01A5WYZIU: Antimicrobial Cooktop Cleaner Silicone Scrubber by Peachy Clean (Qty 3), Predicted Rating: 4.3995772732926435
# - B00VGFKQQQ: Refrigerator Ice maker Water Valve for LG, AP4451762, PS3536019, MJX41178908, Predicted Rating: 3.854826102703327
# - B001E6DM4U:  Broan 424201 ADA Capable Under-Cabinet Range Hood, 190 CFM 42-Inch, White, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 3.9736370299051123
# Bundle Variance of Predicted Rating: 0.04572089748961479
# Bundle IUF: [12.398937143819797, 18.25691813894737, 12.04746477331842, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 15.843431266796065
# Bundle ILD: 0.9812854064515342
# Bundle Unexpectedness: 0.9584835602148356
# -------------------------
# Bundle 5:
# - B01CC7LSF4: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, Kenmore 9490, 46-9490, 469490, ADQ73613402, Advanced, Pack of 2, Predicted Rating: 4.508104384787424
# - B006UNXQIO: Frigidaire FFHT10F2LW 9.9 Cu. Ft. White Counter Depth  Top Freezer Refrigerator - Energy Star, Predicted Rating: 3.854826102703327
# - B0106TG2BA: 6-Pack Replacement MAF1 filter for Essick Air, Kenmore, Emerson - Compatible with Essick Air MA1201, Kenmore 15412, Kenmore 14906, Kenmore 14410, Kenmore 14411, Kenmore 154120, Essick Air MAF-1, Kenmore 29979, Kenmore 29980, Kenmore 29981, Kenmore 29982, Predicted Rating: 3.854826102703327
# - B013PSOBNA: Power Pair Special-LG Turbo Series Ultra-Capacity Laundry System with Steam and Matching Storage Pedestals *GRAPHITE STEEL*(WM4270HVA_DLEX4270V_WDP4V X 2), Predicted Rating: 3.854826102703327
# - B011JGQHR8: 5-Pack Replacement EF-1 Filter for Kenmore - Compatible with Kenmore EF-1, Kenmore 86889, Kenmore 11635922500, Kenmore 11635923500, Kenmore 20-86889, Kenmore EF1, Kenmore KC38KCEN1000, Kenmore 11628014700, Kenmore 11628015700, Kenmore 11628614800, Kenmore 11628614801, Kenmore 11628614803, Kenmore 11628615800, Kenmore 11628615801, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 3.985481759120147
# Bundle Variance of Predicted Rating: 0.06828360221483981
# Bundle IUF: [11.781184707980973, 18.25691813894737, 18.25691813894737, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 16.96177145275409
# Bundle ILD: 0.9677807087541834
# Bundle Unexpectedness: 0.9389708173525388
# -------------------------
# Bundle 6:
# - B01CC7N5PA: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE MSWF, 101820A, 101821B, 101821-B, Advanced, Pack of 2, Predicted Rating: 4.366610793641823
# - B00K5S0OGC: Noa Store LG Replacement Washer Bearing &amp; Seal Kit 4036ER2004A 4280FR4048L 428FR4048E, Predicted Rating: 3.854826102703327
# - B004UKBHKI: 5.3 Cu. Ft. Silhouette Select Beverage Center, Predicted Rating: 3.854826102703327
# - B00W0W8LMK: Refresh Replacement for Samsung DA29-00020A, DA29-00020B, HAF-CIN/EXP, 46-9101 Refrigerator Water Filter (2 Pack), Predicted Rating: 3.8795673732170477
# - B01E06SPA6: PHB920EJES 30 Free-Standing Convection range With Induction 5.3 Cu. Ft. Capacity 5 Elements True European Convection with Precise Air WiFi Connection in Slate, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 3.96213129499377
# Bundle Variance of Predicted Rating: 0.04099273577663999
# Bundle IUF: [11.09704680216898, 18.25691813894737, 18.25691813894737, 8.773102361683113, 18.25691813894737]
# Bundle MIUF: 14.928180716138844
# Bundle ILD: 0.98992053822983
# Bundle Unexpectedness: 0.9811540737715398
# -------------------------
# Bundle 7:
# - B01CC7N5PU: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE MSWF, 101820A, 101821B, 101821-B, Advanced , Pack of 3, Predicted Rating: 4.362872014280058
# - B011P187Y8: LG Rack (3750EL0001C), Predicted Rating: 3.854826102703327
# - B01GAAJJ6Y: Waterdrop UKF8001 NSF 401&amp;53&amp;42 Certified Refrigerator Water Filter, Compatible with Maytag UKF8001, UKF8001AXX, UKF8001P, Whirlpool 4396395, 469006, Filter 4, Puriclean II, Pack of 3, Predicted Rating: 3.854826102703327
# - B009QNZGHY: Icicle Set 8 Cascading Led Illuminated, Predicted Rating: 3.854826102703327
# - B01C6RGS6E: RxAir UVC1001B Filterless Air Purifier with UV-C Sanitizer, Grey, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 3.9564352850186735
# Bundle Variance of Predicted Rating: 0.04129770372317314
# Bundle IUF: [11.411428088002994, 18.25691813894737, 18.25691813894737, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 16.887820128758495
# Bundle ILD: 0.9906639177770575
# Bundle Unexpectedness: 0.9260802113688505
# -------------------------
# Bundle 8:
# - B01CC7LSE0: Waterdrop Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, Kenmore 9490, 46-9490, 469490, ADQ73613402, Standard, Predicted Rating: 4.08909226416551
# - B00ELOMDEW: GE JB750DFWW 30&quot; White Electric Smoothtop Range - Convection, Predicted Rating: 3.854826102703327
# - B010UY7RHE: LG Refrigerator Ice Maker Part AEQ36756901R AEQ36756901 Model LG 79539113600, Predicted Rating: 3.854826102703327
# - B01EMC06X2: GAP CAP - Dual Space-Saving Air Gap Drain For 1 1/2&quot; &amp; 2&quot; Standpipes, Predicted Rating: 3.854826102703327
# - B01BGMU5HS: NAPCO 8544771 Dryer Heat Element, White, Predicted Rating: 4.093164466675575
# -------------------------
# Bundle Average Predicted Rating: 3.9493470077902133
# Bundle Variance of Predicted Rating: 0.013402960530994554
# Bundle IUF: [11.04746477331842, 18.25691813894737, 18.25691813894737, 18.25691813894737, 11.733356182890358]
# Bundle MIUF: 15.51031507461018
# Bundle ILD: 0.9936547269303574
# Bundle Unexpectedness: 0.9650212127450393
# -------------------------
# Bundle 9:
# - B01CA34OU6: Waterdrop NSF 53&amp;42 Certified DA29-00020B Refrigerator Water Filter, Compatible with Samsung DA29-00020B, DA29-00020A, HAF-CIN/EXP, 46-9101, Advanced, Pack of 3, Predicted Rating: 4.115751869779694
# - B00PCN55DC: 5231EL1003B FACTORY OEM ORIGINAL LG KENMORE SEARS LINT SCREEN IN LG BAG, Predicted Rating: 3.854826102703327
# - B00EFH6Q2K: Enagic Kangen Water Leveluk DXII Water Ionizer Machine, Predicted Rating: 3.854826102703327
# - B00A236N60: Kole Imports DB181 Sandwich &amp; Freezer Bag Display, Predicted Rating: 3.854826102703327
# - B01G7RA87Y: Electrolux Perfect Steam EFLS617SIW 4.4 Cu. Ft. Washer with LuxCare Wash and Smart Boost in Island, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 3.907011256118601
# Bundle Variance of Predicted Rating: 0.010893160947902497
# Bundle IUF: [8.436739176532182, 18.25691813894737, 18.25691813894737, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 16.29288234646433
# Bundle ILD: 0.9852311465454864
# Bundle Unexpectedness: 0.9790411740677223
# -------------------------
# Bundle 10:
# - B01CA26LYE: Waterdrop NSF 53&amp;42 Certified DA29-00003G Refrigerator Water Filter, Compatible with Samsung DA29-00003G, Aqua-Pure Plus DA29-00003B, HAFCU1, DA29-00003A, Advanced, Pack of 3, Predicted Rating: 4.548348314395621
# - B00JYLU3X0: PS373087 NEW OEM FACTORY WHIRLPOOL KENMORE MAYTAG DRYER KIT WITH FREE 3392519 FUSE, Predicted Rating: 3.854826102703327
# - B004LDB1CS: Oasis BSE1SRHS w/WTG Odyssey Combination Hot 'N Cold Water Cooler and Refrigerator, Stainless Steel and Black, Predicted Rating: 3.854826102703327
# - B01HAA0HFK: WHIRLPOOL DRAIN PUMP W10130913 W10117829 AP4308966 PS1485610 - 1-3 DAY DELIVERY, Predicted Rating: 3.854826102703327
# - B016LDW6Z6: Ivation 48-Pound Daily Capacity Counter Top Ice Maker - Stainless Steel - 4.5-Liter Water Reservoir - 3 Cube Sizes - Yield 48 Pounds of Ice Daily, Predicted Rating: 3.312697248410307
# -------------------------
# Bundle Average Predicted Rating: 3.885104774183182
# Bundle Variance of Predicted Rating: 0.15405855260694185
# Bundle IUF: [9.50872528935791, 18.25691813894737, 18.25691813894737, 18.25691813894737, 11.291133854285283]
# Bundle MIUF: 15.11412271209706
# Bundle ILD: 0.9908523742317105
# Bundle Unexpectedness: 0.96821001927168
# -------------------------

# %%
# Sort bundles based on the sum of MIUF and average predicted rating
sorted_bundles_2 = sorted(bundle_info_2, key=lambda x: x[1] + x[5], reverse=True)

# Print sorted bundles
for i, (bundle, avg_pred_rating, var_pred_rating, miuf, iuf, ild, uxp) in enumerate(sorted_bundles_2):
    print(f'Bundle {i + 1}:')
    for asin in bundle:
        asin_meta = metadata.loc[metadata['asin'] == asin].reset_index(drop=True)
        print(f"- {asin}: {asin_meta.loc[0, 'title']}, Predicted Rating: {algorithm.predict(user_id, asin).est}")
    
    print('-' * 25)
    print(f'Bundle Average Predicted Rating: {avg_pred_rating}')
    print(f'Bundle Variance of Predicted Rating: {var_pred_rating}')
    print(f'Bundle IUF: {iuf}')
    print(f'Bundle MIUF: {miuf}')
    print(f'Bundle ILD: {ild}')
    print(f'Bundle Unexpectedness: {uxp}')
    print('-' * 25)
# Out:
# Bundle 1:
# - B01CC7LSEA: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, Kenmore 9490, 46-9490, 469490, ADQ73613402, Advanced, Pack of 3, Predicted Rating: 5
# - B00YD3PJWY: Replacement LG LRFD25850ST Refrigerator Water Filter - Compatible LG LT600P, 5231JA2006A, 5231JA2006B Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# - B016PYUW3E: ICEPURE LT700P Refrigerator Water Filter Replacement for LG LT700P , ADQ36006101, ADQ36006102, KENMORE 469690, 9690, RWF1200A,3PACK, Predicted Rating: 4.305546730599942
# - B0029CZQIS: LG 5231JA2006A Refrigerator Water Filter, Predicted Rating: 4.081278903656718
# - B000HJ97D0: Humidifier Filter, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 4.219295567932663
# Bundle Variance of Predicted Rating: 0.18033265101960327
# Bundle IUF: [10.356051330966622, 18.25691813894737, 10.881878707600444, 8.90597895740094, 18.25691813894737]
# Bundle MIUF: 13.331549054772548
# Bundle ILD: 0.9756127222361914
# Bundle Unexpectedness: 0.8354445571773752
# -------------------------
# Bundle 2:
# - B00YU2DNFS: UpStart Battery 2-Pack Replacement Honeywell HCM-315T Humidifier Filter - Compatible Honeywell HAC-504, HAC-504AW Air Filter, Predicted Rating: 3.854826102703327
# - B01CC7N5PA: Waterdrop NSF 53&amp;42 Certified Refrigerator Water Filter, Compatible with GE MSWF, 101820A, 101821B, 101821-B, Advanced, Pack of 2, Predicted Rating: 4.366610793641823
# - B00YD2KOUW: 2-Pack Replacement Samsung RF31FMEDBSR Refrigerator Water Filter - Compatible Samsung DA29-00020B, DA29-00020A, HAF-CIN Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# - B00YD3LVF8: 2-Pack Replacement Jenn-Air JFC2089HES Refrigerator Water Filter - Compatible Jenn-Air UKF8001 Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# - B01G4Z2C50: AQUACREST Replacement DA29-00020B Refrigerator Water Filter, Compatible with Samsung DA29-00020B, DA29-00020A, HAF-CIN/EXP, 46-9101 Water Filter (Pack of 3), Predicted Rating: 4.49791478376219
# -------------------------
# Bundle Average Predicted Rating: 4.085800777102799
# Bundle Variance of Predicted Rating: 0.08174802410306602
# Bundle IUF: [18.25691813894737, 11.09704680216898, 18.25691813894737, 18.25691813894737, 10.542672621281248]
# Bundle MIUF: 15.282094768058466
# Bundle ILD: 0.9746396602811395
# Bundle Unexpectedness: 0.6893828345350537
# -------------------------
# Bundle 3:
# - B00YD2RT9Q: 2-Pack Replacement Maytag MSD2651HES Refrigerator Water Filter - Compatible Maytag UKF8001 Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# - B004WSAHCW: Swift Green Filters SGF-LA50-3 Refrigerator Water Filter, 3-Pack, Predicted Rating: 3.854826102703327
# - B01G4XRT0U: AQUACREST Refrigerator Water Filter, Compatible with LG LT800P, ADQ73613401, ADQ73613402, Kenmore 9490, 46-9490 (Pack of 2), Predicted Rating: 4.8713622738505284
# - B015MFBRCM: Samsung Refrigerator Compatible Replacement Water Filter for DA29-00003G, DA29-00003F, DA29-00003A, DA29-00003B, HAFCU1 - WLF-3G (2-Pack), Predicted Rating: 3.854826102703327
# - B000NY51L6: CRYSTAL QUEST&reg; Whole House Triple 20&quot; x 5.0&quot; Water Filter System, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 4.058133336932768
# Bundle Variance of Predicted Rating: 0.16533532596009803
# Bundle IUF: [18.25691813894737, 18.25691813894737, 12.613061949172646, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 17.128146900992427
# Bundle ILD: 0.9804650622517567
# Bundle Unexpectedness: 0.7862167697189044
# -------------------------
# Bundle 4:
# - B00LQDFJ8I: Whirlpool 71002111 Grease Filter, Predicted Rating: 4.2491284529215045
# - B01HHFUDAC: Crystala LG LT600P Replacement for Refrigerator Water Filter, Compatible LG LT600P, 5231JA2006A, 5231JA2006B, KENMORE 46-9990, 9990, 469990, RWF1000A 3 PACK, Predicted Rating: 3.854826102703327
# - B00MG13AUS: OnePurify RFC0900A3PK UKF8001, Filter 4 Compatible Refrigerator Water Filter (3 Pack), Predicted Rating: 4.388397092185779
# - B00FS71QA8: CA35 Humidifier Water Panel by ClenAir for Aprilaire A35, Predicted Rating: 3.854826102703327
# - B015SPJGIS: 2-Pack Replacement Whirlpool GT1SHTXLQ01 Refrigerator Water Filter - Compatible Whirlpool 8171413, 8171414 Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 4.040400770643453
# Bundle Variance of Predicted Rating: 0.053596511459884345
# Bundle IUF: [11.338054901672775, 18.25691813894737, 9.985455111042995, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 15.218852885911577
# Bundle ILD: 0.9678681877622264
# Bundle Unexpectedness: 0.8863651482650889
# -------------------------
# Bundle 5:
# - B0167MXZKQ: Icepure DA29-00020B Replacement Refrigerator Water Filter, Compatible with Samsung DA29-00020B, DA29-00020A, HAF-CIN/EXP, 46-9101 Water Filter [Pack of 5], Predicted Rating: 3.849493816429635
# - B00ZDOJXV0: UpStart Battery 2-Pack Replacement Sunbeam SCM631 Humidifier Filter - Compatible Sunbeam SWF100P, HWF100 Humidifier Filter, Predicted Rating: 3.854826102703327
# - B00HT39PVQ: Tier1 Replacement for GE GSWF SmartWater, Kenmore 46-9914, 469914, 9914 Refrigerator Water Filter, Predicted Rating: 3.9304835867161745
# - B00C0YPJZU: WaterSentinel WSL-3 Refrigerator Replacement Filter: Fits LG LT700P Filterss (3-Pack), Predicted Rating: 3.854264508691862
# - B0121CFQ4E: Whirlpool W10311524 AIR1 Refrigerator Compatible Air Filter - Whirlpool AIR 1 - 2 Pack, Predicted Rating: 4.593205796007614
# -------------------------
# Bundle Average Predicted Rating: 4.016454762109722
# Bundle Variance of Predicted Rating: 0.08406765146569647
# Bundle IUF: [11.542672621281248, 18.25691813894737, 10.008990625503785, 10.092011212271682, 10.847527202809669]
# Bundle MIUF: 12.149623960162751
# Bundle ILD: 0.9751574297228386
# Bundle Unexpectedness: 0.8344787834407589
# -------------------------
# Bundle 6:
# - B00FKIC348: Frigidaire 240396002 Refrigerator Water Filter Head Genuine Original Equipment Manufacturer (OEM) Part, Predicted Rating: 3.854826102703327
# - B00NMLGQJI: 3 X WLF-01 - Replacement filter for LT700P, ADQ36006101 - Triple Pack, Predicted Rating: 4.46979163407459
# - B00TUR5DLU: Certified Appliance Accessories Braided Stainless Steel Ice Maker Connector, 6ft, Predicted Rating: 3.854826102703327
# - B00ZDPRWVM: UpStart Battery 6-Pack Replacement Bionaire BCM7309 Humidifier Filter - Compatible Bionaire BWF100, HWF100 Humidifier Filter, Predicted Rating: 3.854826102703327
# - B00YD3NJAS: Replacement Samsung RS261 Refrigerator Water Filter - Compatible Samsung DA29-00020B, DA29-00020A, HAF-CIN Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 3.97781920897758
# Bundle Variance of Predicted Rating: 0.06050921676395843
# Bundle IUF: [18.25691813894737, 10.789312588864373, 18.25691813894737, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 16.763397028930772
# Bundle ILD: 0.9604542296687552
# Bundle Unexpectedness: 0.8856000677550456
# -------------------------
# Bundle 7:
# - B00YD393O4: 3-Pack Replacement Samsung RF323TEDBSR/AA Refrigerator Water Filter - Compatible Samsung DA29-00020B, DA29-00020A, HAF-CIN Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# - B008Q9BMI6: Kenmore 9915 Genuine Kenmore Refrigerator Water Filter for KENMORE,KENMORE Elite Genuine Original Equipment Manufacturer (OEM), Predicted Rating: 4.383464014484328
# - B00AI6MQL2: Think Crucial 6 Replacement for ReliOn WF813 Humidifier Wick Filters Fit RCM832, RCM-832N, DH-832 &amp; DH-830, Compatible With Part # WF813, Predicted Rating: 3.875735873656319
# - B00FCBLKNS: EcoAqua EFF-6022A Replacement for GE MSWF, 2-Pack, Predicted Rating: 3.854826102703327
# - B015SOTB8O: 2-Pack Replacement Hotpoint HSM25GFRFSA Refrigerator Water Filter - Compatible Hotpoint MWF, MWFP Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 3.964735639250126
# Bundle Variance of Predicted Rating: 0.04389894583476484
# Bundle IUF: [18.25691813894737, 12.502030636783902, 12.37427508958553, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 15.929412028642309
# Bundle ILD: 0.9734811902314935
# Bundle Unexpectedness: 0.7700473613335774
# -------------------------
# Bundle 8:
# - B00W0TIZE2: Refresh Replacement for Samsung Aqua-Pure Plus DA29-00003G, DA29-00003A, DA2900002B, DA2900003, DA2900003F, DA290002, HAFCU1, HAFIN2 and Waterdrop WD-DA-29-00003G Refrigerator Water Filter (3 Pack), Predicted Rating: 3.418272928135376
# - B00JGVM39A: Tier1 Replacement for LG LT600P 5231JA2006A, 5231JA2006B, Kenmore 46-9990, 9990, 469990, 5231JA2006F, 5231JA2005A Refrigerator Water Filter 3 Pack, Predicted Rating: 4.464288870864057
# - B00FBCO080: Two 12527304, WF401, WF30, WF40 and WF401T Alternative Replacement Refrigerator Water Filter Cartridges by KleenWater - Free Wall Mount Bottle Opener, Predicted Rating: 3.854826102703327
# - B00438PNRK: Certified Appliance Accessories IM48SS Ice 4-Feet Maker Connector, Predicted Rating: 3.854826102703327
# - B00ANNTNZW: Whirlpool WHKF-IMTO Inline Refrigerator Water Filter System - .25 in. Quick Connect Fittings, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 3.8894080214218834
# Bundle Variance of Predicted Rating: 0.11120879889764235
# Bundle IUF: [9.80570702711504, 11.556478420806277, 18.25691813894737, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 15.226587972952686
# Bundle ILD: 0.975316220774028
# Bundle Unexpectedness: 0.9027905762017575
# -------------------------
# Bundle 9:
# - B00P9JZPDO: Think Crucial 3 Water Purifier Filter Fits GE Smart Water Refrigerator, Fits MWF, MWF3PK, MWFA, MWFAP, MWFDS, MWFINT, 46-9991, EFF-6013A, Premium Filtration, Predicted Rating: 3.854826102703327
# - B00KZESETK: HDX FML-2 Replacement Water Filter / Purifier for LG Refrigerators (2 Pack), Predicted Rating: 3.854826102703327
# - B003A0GNQC: 2 Pack Refrigerator Water Filter 1 | Replacement Pur Water Filter, Predicted Rating: 3.854826102703327
# - B00YD3D9OY: 3-Pack Replacement Maytag WF-50 Refrigerator Water Filter - Compatible Maytag WF-50 Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# - B00YD3O6PU: 2-Pack Replacement Samsung RFG237AABP Refrigerator Water Filter - Compatible Samsung DA29-00003G, Samsung DA29-00003B, Samsung DA29-00003A Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# -------------------------
# Bundle Average Predicted Rating: 3.854826102703327
# Bundle Variance of Predicted Rating: 0.0
# Bundle IUF: [18.25691813894737, 18.25691813894737, 18.25691813894737, 18.25691813894737, 18.25691813894737]
# Bundle MIUF: 18.25691813894737
# Bundle ILD: 0.9791312172295079
# Bundle Unexpectedness: 0.7247491743735126
# -------------------------
# Bundle 10:
# - B00YD3C39G: 3-Pack Replacement Jenn-Air JFC2089HPY Refrigerator Water Filter - Compatible Jenn-Air UKF8001 Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# - B00YD2MW6G: 2-Pack Replacement Samsung RF263BEAEBC/AA-0001 Refrigerator Water Filter - Compatible Samsung DA29-00020B, DA29-00020A, HAF-CIN Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# - B00YD2HVG2: Replacement Samsung RS265TDRS/XAA 02 Refrigerator Water Filter - Compatible Samsung DA29-00020B, DA29-00020A, HAF-CIN Fridge Water Filter Cartridge, Predicted Rating: 3.854826102703327
# - B00YU2M7JQ: UpStart Battery 3-Pack Replacement Holmes HM1850 Humidifier Filter - Compatible Holmes HWF65, Type C Air Filter, Predicted Rating: 3.854826102703327
# - B00UXG4WR8: EveryDrop by Whirlpool Refrigerator Water Filter 1 (Pack of 1) (Packaging may vary), Predicted Rating: 3.9101145367454926
# -------------------------
# Bundle Average Predicted Rating: 3.86588378951176
# Bundle Variance of Predicted Rating: 0.0004890897502135863
# Bundle IUF: [18.25691813894737, 18.25691813894737, 18.25691813894737, 18.25691813894737, 8.127635122002404]
# Bundle MIUF: 16.231061535558375
# Bundle ILD: 0.96437341009287
# Bundle Unexpectedness: 0.5482808397601266
# -------------------------

# %%
# Sample data
bundles_list = [f'{i+1}' for i in range(10)]

x = np.arange(len(bundles_list))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, bundle_data[0]['average_predicted_rating'], width, label='Without Diversity')
rects2 = ax.bar(x, bundle_data[1]['average_predicted_rating'], width, label='Bundle Function')
rects3 = ax.bar(x + width, bundle_data[2]['average_predicted_rating'], width, label='Bundle Partition')

ax.set_xlabel('Bundles')
ax.set_ylabel('Average Predicted Ratings')
ax.set_title('Average Predicted Ratings by Method and Bundle')
ax.set_xticks(x)
ax.set_xticklabels(bundles_list)
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
data = [bundle_data[0]['variance_predicted_rating'], bundle_data[1]['variance_predicted_rating'], bundle_data[2]['variance_predicted_rating']]

fig, ax = plt.subplots()
ax.boxplot(data, labels=['Without Diversity', 'Bundle Function', 'Bundle Partition'])

ax.set_xlabel('Methods')
ax.set_ylabel('Variance in Predicted Ratings')
ax.set_title('Variance in Predicted Ratings by Method')

plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(bundles_list, bundle_data[0]['miuf'], marker='o', label='Without Diversity')
ax.plot(bundles_list, bundle_data[1]['miuf'], marker='o', label='Bundle Function')
ax.plot(bundles_list, bundle_data[2]['miuf'], marker='o', label='Bundle Partition')

ax.set_xlabel('Bundles')
ax.set_ylabel('MIUF')
ax.set_title('MIUF by Method and Bundle')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %%
print('ILD for the bundle without diversity:')
for i, ild in enumerate(ilds_0):
    print(f'- Bundle {i + 1}: {ild}')
print(f'Mean: {np.mean(ilds_0)}')
# Out:
# ILD for the bundle without diversity:
# - Bundle 1: 0.17487819941764163
# - Bundle 2: 0.21848719234874486
# - Bundle 3: 0.2985700307844671
# - Bundle 4: 0.3120348970098955
# - Bundle 5: 0.46579187532787864
# - Bundle 6: 0.528685227062798
# - Bundle 7: 0.5130283366463076
# - Bundle 8: 0.32967786267243293
# - Bundle 9: 0.5464017407588593
# - Bundle 10: 0.5303037116683459
# Mean: 0.3917859073697371

# %%
print('ILD for bundle function:')
for i, ild in enumerate(ilds_1):
    print(f'- Bundle {i + 1}: {ild}')
print(f'Mean: {np.mean(ilds_1)}')
# Out:
# ILD for bundle function:
# - Bundle 1: 0.9695384634503403
# - Bundle 2: 0.9389708173525388
# - Bundle 3: 0.9650212127450393
# - Bundle 4: 0.9260802113688505
# - Bundle 5: 0.9778870715550649
# - Bundle 6: 0.9811540737715398
# - Bundle 7: 0.9584835602148356
# - Bundle 8: 0.9790411740677223
# - Bundle 9: 0.96821001927168
# - Bundle 10: 0.9458339986812376
# Mean: 0.961022060247885

# %%
print('ILD for bundle partition:')
for i, ild in enumerate(ilds_2):
    print(f'- Bundle {i + 1}: {ild}')
print(f'Mean: {np.mean(ilds_2)}')
# Out:
# ILD for bundle partition:
# - Bundle 1: 0.8354445571773752
# - Bundle 2: 0.8344787834407589
# - Bundle 3: 0.5482808397601266
# - Bundle 4: 0.7862167697189044
# - Bundle 5: 0.7247491743735126
# - Bundle 6: 0.9027905762017575
# - Bundle 7: 0.8856000677550456
# - Bundle 8: 0.6893828345350537
# - Bundle 9: 0.7700473613335774
# - Bundle 10: 0.8863651482650889
# Mean: 0.78633561125612

# %%
# Create a DataFrame to hold ILD values
ild_data = {
    'Method': ['Without Diversity'] * len(ilds_0) + ['Bundle Function'] * len(ilds_1) + ['Bundle Partition'] * len(ilds_2),
    'ILD': ilds_0 + ilds_1 + ilds_2
}
ild_df = pd.DataFrame(ild_data)

# Create a box plot
plt.figure(figsize=(8, 6))
ild_df.boxplot(column='ILD', by='Method')
plt.title('ILD Distribution by Bundle Creation Method')
plt.ylabel('ILD')
plt.show()
